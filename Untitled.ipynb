# %%
# import modules
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# import functions from hub_simulation.py
os.chdir('giant-hub-filament-systems')
from hub_simulation import *
os.chdir('..')

# open fits file
hdu = fits.open('satexample1.fits')[0]
header = hdu.header
data = hdu.data
sat_area = np.zeros(data.shape,bool)
sat_area[data==data.min()] = True

# axis values from header
x0,y0 = header['crval1'],header['crval2']
dx,dy = header['cdelt1'],header['cdelt2']
nx,ny = header['naxis1'],header['naxis2']
x = x0 + dx*np.arange(0,nx)
y = y0 + dy*np.arange(0,ny)
grid = np.meshgrid(x,y)

# plot and show image
fig = plt.figure(figsize=(30,15*ny/nx))
ax1 = plt.axes([0,0,0.45,1])
ax2 = plt.axes([0.55,0,0.45,1])
ax1.imshow(data,origin='lower',cmap='hot')
ax2.imshow(sat_area,origin='lower')
ax1.set_xticklabels(np.around(x,4))
ax1.set_yticklabels(np.around(y,4))
ax2.set_xticklabels(np.around(x,4))
ax2.set_yticklabels(np.around(y,4))
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: UserWarning: FixedFormatter should only be used together with FixedLocator
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: FixedFormatter should only be used together with FixedLocator
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
n = 4
mu_vals = np.array([[35.],
                    []])
image = fit(grid,data,sat_area,peaks=6)[1]

fig = plt.figure(figsize=(10,10*ny/nx))
ax = plt.axes()
ax.imshow(image,origin='lower',cmap='hot')
xticks = ax.get_xticks()
yticks = ax.get_yticks()
ax.set_xticklabels(np.around(x,4))
ax.set_yticklabels(np.around(y,4))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-e93c551ad6b7> in <module>
# ----> 1 image = fit(grid,data,sat_area,peaks=6)[1]
#       2
#       3 fig = plt.figure(figsize=(10,10*ny/nx))
#       4 ax = plt.axes()
#       5 ax.imshow(image,origin='lower',cmap='hot')
#
# ~/FCUP/Internships/IAstro/giant-hub-filament-systems/hub_simulation.py in fit(grid, data, sat, peaks)
#      75                         k += 1
#      76
# ---> 77         params,cov = curve_fit(gaussian2Dmult,fit_x,fit_data,guess_params)
#      78         image = np.empty(data.shape)
#      79         image[sat] = gaussian2Dmult((X[sat],Y[sat]),*params)
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     787         cost = np.sum(infodict['fvec'] ** 2)
#     788         if ier not in [1, 2, 3, 4]:
# --> 789             raise RuntimeError("Optimal parameters not found: " + errmsg)
#     790     else:
#     791         # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 7400.

# %%
header['crval2']/header['crpix2']
# Out:
# 0.0015737910594941324

# %%
header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                  201 / Axis length
# NAXIS2  =                  175 / Axis length
# EXTEND  =                    T / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2021-07-16T15:29:34' / Date FITS file was generated
# IRAF-TLM= '2021-07-16T15:29:34' / Time of last modification
# CTYPE1  = 'GLON-TAN'           /
# CTYPE2  = 'GLAT-TAN'           /
# CRPIX1  =    -551.999999999999 /
# CRPIX2  =    -84.9999999999992 /
# CRVAL1  =        35.3148107803 /
# CRVAL2  =      -0.133772240057 /
# CDELT1  =    -0.00166666666667 /
# CDELT2  =     0.00166666666667 /
# RPE_APPL=                    0 /RPE correction switch
# WAVELEN =                  250 /Wavelength of observation in mirons
# RPE_AL_N=              1.03623 /arcsec along nom scan dir
# RPE_AC_N=           -0.0186617 /arcsec across nom scan dir, not appl
# RPE_AL_O=             0.966183 /arcsec along ortho scan dir
# RPE_AC_O=            0.0148887 /arcsec across ortho scan dir, not appl
# BUNIT   = 'MJy/sr  '           /
# BEAMSURF=              373.265 /beam solid angle used for intercal
# SCANDIR1= 'Field   '           /Scanning direction 1
# SCANDIR2= 'Field   '           /Scanning direction 2
# OBSDAY_1=                  712 /Observation day 1
# OBSDAY_2=                  712 /Observation day 2
# OBSID_1 = '1342219631'         /ObsID 1
# OBSID_2 = '1342219630'         /ObsID 2
# OBSST_1 = '2011-04-26T16:39:59Z' /Obs start date and time 1
# OBSST_2 = '2011-04-26T13:48:27Z' /Obs start date and time 2
# MED_WIN = '20      '           /
# MED_STEP= '20      '           /
# FLAG_PER= '38      '           /
# MASK_CL = '3       '           /
# MASK_GR = '3       '           /
# REGS_LON=       -1.52464944432 /gal lon shift in arcsec
# REGS_LAT=       -3.76584642735 /gal lat shift in arcsec
# OFSET_AP=                    1 /
# OFSET_VA=              283.912 /from intercal IRAS-Planck-HSO
# GAIN_AP =                    0 /
# GAIN_VA =                    1 /from intercal IRAS-Planck-HSO
# WCSDIM  =                    2
# CD1_1   =    -0.00166666666667
# CD2_2   =     0.00166666666667
# LTV1    =               -1496.
# LTV2    =                -975.
# LTM1_1  =                   1.
# LTM2_2  =                   1.
# WAT0_001= 'system=image'
# WAT1_001= 'wtype=tan axtype=glon'
# WAT2_001= 'wtype=tan axtype=glat'
