# %%
# import modules
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from hub_simulation import fit

    
# open fits file
# hdu = fits.open('sat_images/satexample1.fits')[0]
hdu = fits.open('sat_images/im250_sat_1_fine.fits')[0]
header = hdu.header
data0 = hdu.data
#data0[data0==np.min(data0)] = np.nan
sat_area = np.zeros(data0.shape,bool)
sat_area[np.isnan(data0)] = True
sat_area[data0==0] = True

# axis values from header
x0,y0 = header['crpix1'],header['crpix2']
dx,dy = header['cdelt1'],header['cdelt2']
nx,ny = header['naxis1'],header['naxis2']
x = x0 + dx/abs(dx)*np.arange(0,nx)
y = y0 + dy/abs(dy)*np.arange(0,ny)
grid = np.meshgrid(x,y)

# plot and show image
fig = plt.figure(figsize=(30,15*ny/nx))
ax1 = plt.axes([0,0,0.45,1])
ax2 = plt.axes([0.55,0,0.45,1])
ax1.imshow(data0,origin='lower',extent=(x[0],x[-1],y[0],y[-1]))
ax2.imshow(sat_area,origin='lower',extent=(x[0],x[-1],y[0],y[-1]))
plt.show()

lim1 = 400
lim2 = 600
data0 = data0[lim1:lim2,lim1:lim2]
sat_area = sat_area[lim1:lim2,lim1:lim2]
x = x[lim1:lim2]
y = y[lim1:lim2]
grid = np.meshgrid(x,y)
fig = plt.figure(figsize=(30,15*ny/nx))
ax1 = plt.axes([0,0,0.45,1])
ax2 = plt.axes([0.55,0,0.45,1])
ax1.imshow(data0,origin='lower',extent=(x[0],x[-1],y[0],y[-1]))
ax2.imshow(sat_area,origin='lower',extent=(x[0],x[-1],y[0],y[-1]))
plt.show()

# %%
n_peaks = 1

params,image = fit(grid,data0,sat_area,peaks=n_peaks)
min_val,max_val = np.min(np.log10(image)),np.max(np.log10(image))

fig,axs = plt.subplots(2,1,figsize=(15,15*ny/nx))
ax1 = axs[0].imshow(np.log10(image),origin='lower',extent=(x[0],x[-1],y[0],y[-1]),vmin=min_val,vmax=max_val)
ax2 = axs[1].imshow(np.log10(data0),origin='lower',extent=(x[0],x[-1],y[0],y[-1]),vmin=min_val,vmax=max_val)
cax = plt.axes([0.7, 0.1, 0.01, 0.8])
for i in range(n_peaks):
    axs[0].plot(params[i*3],params[i*3+1],'.')
plt.colorbar(ax1,cax=cax)
plt.show()

plt.imshow(np.log10(np.abs(image-data0)),origin='lower')
plt.colorbar()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log10
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log10
#   from ipykernel import kernelapp as app

# %%
a = fits.writeto('sat_images_corrected/im250_sat_1_fixed.fits',image,header,overwrite=True)

# %%
header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                  995 / Axis length
# NAXIS2  =                  995 / Axis length
# EXTEND  =                    T / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2021-07-26T16:36:40' / Date FITS file was generated
# IRAF-TLM= '2021-07-26T16:36:40' / Time of last modification
# CTYPE1  = 'GLON-TAN'           / galactic longitude, gnomonic projection
# CTYPE2  = 'GLAT-TAN'           / galactic latitude, gnomonic projection
# CRPIX1  =                  86. / Pixel coordinate of reference point
# CRPIX2  =                 686. / Pixel coordinate of reference point
# CRVAL1  =       301.273449784  / [deg] Coordinate value at reference point
# CRVAL2  =     -0.162607353597  / [deg] Coordinate value at reference point
# CDELT1  =  -3.3333333333400E-4 / [deg] Coordinate increment at reference point
# CDELT2  =  3.33333333334001E-4 / [deg] Coordinate increment at reference point
# RPE_APPL=                    0 /RPE correction switch
# WAVELEN =                  250 /Wavelength of observation in mirons
# RPE_AL_N=              1.02419 /arcsec along nom scan dir
# RPE_AC_N=           -0.0366705 /arcsec across nom scan dir, not appl
# RPE_AL_O=             0.967764 /arcsec along ortho scan dir
# RPE_AC_O=            0.0316682 /arcsec across ortho scan dir, not appl
# BUNIT   = 'MJy/sr  '           /
# BEAMSURF=              373.265 /beam solid angle used for intercal
# SCANDIR1= 'Field   '           /Scanning direction 1
# SCANDIR2= 'Field   '           /Scanning direction 2
# OBSDAY_1=                  459 /Observation day 1
# OBSDAY_2=                  459 /Observation day 2
# OBSID_1 = '1342203084'         /ObsID 1
# OBSID_2 = '1342203083'         /ObsID 2
# OBSST_1 = '2010-08-16T00:06:14Z' /Obs start date and time 1
# OBSST_2 = '2010-08-15T21:14:42Z' /Obs start date and time 2
# MED_WIN = '20      '           /
# MED_STEP= '20      '           /
# FLAG_PER= '38      '           /
# MASK_CL = '3       '           /
# MASK_GR = '3       '           /
# REGS_LON=       -1.92945084547 /gal lon shift in arcsec
# REGS_LAT=       -2.84269090909 /gal lat shift in arcsec
# OFSET_AP=                    1 /
# OFSET_VA=              174.052 /from intercal IRAS-Planck-HSO
# GAIN_AP =                    0 /
# GAIN_VA =                    1 /from intercal IRAS-Planck-HSO
# WCSAXES =                    2 / Number of coordinate axes
# CUNIT1  = 'deg'                / Units of coordinate increment and value
# CUNIT2  = 'deg'                / Units of coordinate increment and value
# LONPOLE =                180.0 / [deg] Native longitude of celestial pole
# LATPOLE =      -0.162607353597 / [deg] Native latitude of celestial pole
# MJDREF  =                  0.0 / [d] MJD of fiducial time
# WCSDIM  =                    2
# CD1_1   =  -3.3333333333400E-4
# CD2_2   =  3.33333333334001E-4
# LTV1    =                  -4.
# LTV2    =                  -4.
# LTM1_1  =                   5.
# LTM2_2  =                   5.
# WAT0_001= 'system=image'
# WAT1_001= 'wtype=tan axtype=glon'
# WAT2_001= 'wtype=tan axtype=glat'

# %%
hdu_fitted = fits.open('sat_images_corrected/im250_sat_1_fixed.fits')
plt.imshow(np.log10(hdu.data[75:125,75:125]),origin='lower')
plt.show()
